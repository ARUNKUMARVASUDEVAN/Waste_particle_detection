# %%
# %pip install boto3
# Out:
# ...
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      -------------------------------------- 48.9/48.9 kB 840.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    ----------- ---------------------------- 41.0/139.3 kB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 92.2/139.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 139.3/139.3 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.9 MB 991.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/11.9 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.2/11.9 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.9 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.9 MB 1.2 MB/s eta 0:00:10
# ...

# %%
#downloading data from s3

import boto3

AWS_ACCESS_KEY_ID = 'AKIAU7GPPQUUESQEHPF3'
AWS_SECRET_ACCESS_KEY = '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'
AWS_DEFAULT_REGION ='us-east-1'


s3 = boto3.client('s3', 
                  aws_access_key_id=AWS_ACCESS_KEY_ID, 
                  aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
                  region_name=AWS_DEFAULT_REGION)

try:
    s3.download_file(Bucket="my-first-backup-bucket7994241",
                     Key="waste-detection.zip", Filename="D:/Waste_particle_detection/data/waste_data.zip")
except Exception as e:
    print(f"Error: {e}")

# %%
! pip install gdown
# Out:
# ...
#   Using cached gdown-4.7.1-py3-none-any.whl (15 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...

# %%
import gdown

url = "https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=share_link"

file_id = url.split("/")[-2]
print(file_id)
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id)
print("Data downloaded!")
# Out:
# 1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# Downloading...
# From (uriginal): https://drive.google.com/uc?/export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# From (redirected): https://drive.google.com/uc?/export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61&confirm=t&uuid=bccc1156-05e0-47aa-902d-958f201d8185
# To: d:\Waste_particle_detection\reseach\waste-detection.zip
# 100%|██████████| 40.1M/40.1M [00:23<00:00, 1.74MB/s]
# Data downloaded!
